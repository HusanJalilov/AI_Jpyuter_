# %% [markdown]
# <a href="https://colab.research.google.com/github/HusanJalilov/AI_Jpyuter_/blob/main/3%20Modul%20tasks/HDF5_formati.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Kerakli Jadval.xlsx", index_col="Joy", names=['Joy','axolisi','Yeri','Ishlab chiqarish'])
df
# Out:
#              axolisi  Yeri Ishlab chiqarish
# Joy
# Andijon       123763    14            Kiyim
# Jizzax        763364    45              KIA
# Toshkent      769736    23        Yalpi MHM
# Buxoro        893562    65           qalpoq
# Navoiy        123765    65            Kitob
# QRR           345876    34           daftar
# Termiz        425987    56            biton
# Qarshi        345876    78            sugal
# Xorazm        789435    65           shakar
# Namangan      345987    43            massi
# Farg'ona      234876   456            romka
# Sirdaryo         453    32           diller
# Maskva        873654    45           ferari
# Berlin           872    67           starka
# Parij         678946    89            polga
# Piter         345984    34         zastavka
# Osh           247357    56            prava
# Bishkent      346975    76       Lambarjino
# Dankuk        445566    34          mustang
# Seul          762367    56            KIAAA
# ...

# %%
df.to_csv("New Jadval.csv")

# %%
pd.read_csv("New Jadval.csv")  # data frame ko'rinishida ochadi
# Out:
#            Joy   axolisi  Yeri Ishlab chiqarish
# 0      Andijon    123763    14            Kiyim
# 1      Jizzax     763364    45              KIA
# 2     Toshkent    769736    23        Yalpi MHM
# 3       Buxoro    893562    65           qalpoq
# 4       Navoiy    123765    65            Kitob
# 5          QRR    345876    34           daftar
# 6       Termiz    425987    56            biton
# 7       Qarshi    345876    78            sugal
# 8       Xorazm    789435    65           shakar
# 9     Namangan    345987    43            massi
# 10    Farg'ona    234876   456            romka
# 11    Sirdaryo       453    32           diller
# 12      Maskva    873654    45           ferari
# 13      Berlin       872    67           starka
# 14       Parij    678946    89            polga
# 15       Piter    345984    34         zastavka
# 16         Osh    247357    56            prava
# 17    Bishkent    346975    76       Lambarjino
# 18      Dankuk    445566    34          mustang
# ...

# %%
df2=pd.read_excel("oliy talim.xlsx")
df2.head()
# Out:
#              Hudud  2010 /\n2011  2011 /\n2012  2012 /\n2013  2013 /\n2014
# 0  Toshkent shahri            33            33            32            34
# 1          Uchtepa             2             2             2             2
# 2        Yunusobod             3             3             3             4
# 3   Mirzo Ulug‘bek             6             6             6             6
# 4          Mirobod             5             5             5             5

# %%
pd.read_excel("kerak.xlsx")
# Out:
#            Joy   axolisi
# 0      Andijon    123763
# 1      Jizzax     763364
# 2     Toshkent    769736
# 3       Buxoro    893562
# 4       Navoiy    123765
# 5          QRR    345876
# 6       Termiz    425987
# 7       Qarshi    345876
# 8       Xorazm    789435
# 9     Namangan    345987
# 10    Farg'ona    234876
# 11    Sirdaryo       453
# 12      Maskva    873654
# 13      Berlin       872
# 14       Parij    678946
# 15       Piter    345984
# 16         Osh    247357
# 17    Bishkent    346975
# 18      Dankuk    445566
# 19        Seul    762367
# 20      Manago  34576423
# 21   Las veges    333343
# 22  Vashington    343434
# 23       Mango   6576765
# 24      Anqara  76577657
# 25      London    765756
# 26       Zvera      7657

# %%
hdf=pd.HDFStore("data.h5")

# %%
df.head()
# Out:
#           axolisi  Yeri Ishlab chiqarish
# Joy
# Andijon    123763    14            Kiyim
# Jizzax     763364    45              KIA
# Toshkent   769736    23        Yalpi MHM
# Buxoro     893562    65           qalpoq
# Navoiy     123765    65            Kitob

# %%
df2.head()
# Out:
#              Hudud  2010 /\n2011  2011 /\n2012  2012 /\n2013  2013 /\n2014
# 0  Toshkent shahri            33            33            32            34
# 1          Uchtepa             2             2             2             2
# 2        Yunusobod             3             3             3             4
# 3   Mirzo Ulug‘bek             6             6             6             6
# 4          Mirobod             5             5             5             5

# %%
hdf.put('statistika',df)

# %%
hdf.put('malumot',df2)

# %%
hdf.keys()
# Out:
# ['/malumot', '/statistika']

# %%
hdf.keys()
# Out:
# ['/malumot', '/statistika']

# %%
data1= pd.read_hdf("data.h5", key="malumot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-a7afdb86bb32> in <module>()
# ----> 1 data1= pd.read_hdf("data.h5", key="malumot")
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     387             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     388
# --> 389         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     390         # can't auto open/close if we are using an iterator
#     391         # so delegate to the iterator
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     551         self._fletcher32 = fletcher32
#     552         self._filters = None
# --> 553         self.open(mode=mode, **kwargs)
# ...
