# %% [markdown]
# <a href="https://colab.research.google.com/github/HusanJalilov/AI_Jpyuter_/blob/main/3%20Modul%20tasks/Fayldan_o'qish1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Texnikumlari soni.xlsx")
df.head()
# Out:
#               Texnikumlari soni  Unnamed: 1  ... Unnamed: 10 Unnamed: 11
# 0  (o‘quv yili boshiga, birlik)         NaN  ...         NaN         NaN
# 1                           NaN         NaN  ...         NaN         NaN
# 2                           NaN  2010/ 2011  ...  2019/ 2020  2020/ 2021
# 3               Toshkent shahri           -  ...           -          11
# 4                     tumanlar:         NaN  ...         NaN         NaN
#
# [5 rows x 12 columns]

# %%
df2=pd.read_excel("Oliy ta՚lim tashkilotlar soni.xlsx")
df2
# Out:
#                 Oliy ta՚lim tashkilotlar soni  ... Unnamed: 15
# 0                (o‘quv yili boshiga, birlik)  ...         NaN
# 1                                         NaN  ...         NaN
# 2                                         NaN  ...         NaN
# 3                             Toshkent shahri  ...         NaN
# 4                                   tumanlar:  ...         NaN
# 5                                     Uchtepa  ...         NaN
# 6                                    Bektemir  ...         NaN
# 7                                   Yunusobod  ...         NaN
# 8                              Mirzo Ulug‘bek  ...         NaN
# 9                                     Mirobod  ...         NaN
# 10                               Shayhоntohur  ...         NaN
# 11                                    Olmazor  ...         NaN
# 12                                    Sergeli  ...         NaN
# 13                                 Yakkasaroy  ...         NaN
# ...

# %%
df
